# %%
import pandas as pd
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
from collections import Counter

# %%
df=pd.read_csv("DataSet.csv")
df.head()
# Out:
#    Unnamed: 0   Location                         Job_Description  \
# 0           0      DELHI                 SALES & MARKETING AGENT
# 1           1  BENGALURU            GERMAN TRAINING COORDINATOR
# 2           2  BENGALURU  PROCESS ENGINEER
# 3           3  BENGALURU                SENIOR SOFTWARE ENGINEER
# 4           4  BENGALURU                        GRAPHIC DESIGNER
#
#                               Sector         Eligibility    salary  Month  \
# 0  Sales/Retail/Business Development  BTech BE  ME MTech   35000.0      7
# 1           Customer Service/Support        BSc  Diploma   50000.0      9
# 2                        Engineering           MPhil PhD  150000.0      7
# 3            IT/Software Development  BTech BE  ME MTech   60000.0      5
# 4                    Creative/Design     BDS  MBBS  BAMS   30000.0      7
#
#    vacancies
# 0        8.0
# 1        8.0
# 2        3.0
# 3        2.0
# 4        2.0

# %%
a=Counter(df["Location"]).most_common(20)
city=[];count=[]
for i in range(len(a)):
    city.append(a[i][0])
    count.append(a[i][1])

# %%
plt.figure(figsize = (10, 12))
plt.bar(city, count)
plt.xlabel("Locations")
plt.ylabel("Job Opportunities")
plt.xticks(city, rotation = "60")
plt.title("Top 20 JOB Opportunities")
plt.ylim(0,100 )
# Out:
# <img src="data:image/png;base64,..." width="999.6">
# (0, 100)

# %%
a=Counter(df["Sector"]).most_common(20)
sector=[];count_sector=[]
for i in range(len(a)):
    sector.append(a[i][0])
    count_sector.append(a[i][1])
sector
# Out:
# ['IT/Software Development',
#  'Engineering',
#  'Customer Service/Support',
#  'Marketing',
#  'Sales/Retail/Business Development',
#  'Creative/Design',
#  'Editorial/Writing',
#  'Quality Assurance/Quality Control',
#  'Administration',
#  'Education/Training',
#  'Installation/Maintenance/Repair',
#  'Project/Program Management',
#  'Manufacturing/Production/Operations',
#  'Medical',
#  'Pharmaceutical',
#  'Media/Journalism/Publishing',
#  'Biotech/R&D/Science',
#  'Tourism/Travel',
#  'Research',
#  'Logistics/Transportation']

# %%
plt.figure(figsize = (10,20))
plt.bar(sector, count_sector)
plt.xlabel("Sector")
plt.ylabel("Job Opportunities")
plt.xticks(sector, rotation = "60")
plt.title("Job Opportunities in Top 20 Industries")
# Out:
# <img src="data:image/png;base64,..." width="1850.5666666666666">
# Text(0.5, 1.0, 'Job Opportunities in Top 20 Industries')

# %%
#a=Counter(df["Salary"])
a=Counter(df["Job_Description"]).most_common(20)
JOB=[];count_sector=[]
for i in range(len(a)):
    JOB.append(a[i][0])
    count_sector.append(a[i][1])
JOB
# Out:
# ['GRAPHIC DESIGNER',
#  'CALL CENTER AGENT',
#  'SALES ENGINEER',
#  'SOCIAL MEDIA SPECIALIST',
#  'CUSTOMER SERVICE REPRESENTATIVE',
#  'CUSTOMER SERVICE AGENT',
#  'WEB DEVELOPER',
#  'TELESALES AGENT',
#  'MARKETING SPECIALIST',
#  'SENIOR .NET DEVELOPER',
#  'PHP DEVELOPER',
#  'SOFTWARE DEVELOPER',
#  'SENIOR PHP DEVELOPER',
#  'IOS DEVELOPER',
#  'JAVA DEVELOPER',
#  '.NET DEVELOPER',
#  'WEB DESIGNER',
#  'SENIOR JAVA DEVELOPER',
#  'GRAPHIC DESIGNER ',
#  'ANDROID DEVELOPER']

# %%
plt.figure(figsize = (10,20))
plt.bar(JOB, count_sector)
plt.xlabel("Profession")
plt.ylabel("Job Opportunities")
plt.xticks(JOB, rotation = "60")
plt.title("Job Opportunities in Top 20 Profession")
# Out:
# <img src="data:image/png;base64,..." width="999.6">
# Text(0.5, 1.0, 'Job Opportunities in Top 20 Profession')

# %%
plt.savefig("profession-vac.png")

# %%
df.head()
# Out:
#    Unnamed: 0   Location                         Job_Description  \
# 0           0      DELHI                 SALES & MARKETING AGENT
# 1           1  BENGALURU            GERMAN TRAINING COORDINATOR
# 2           2  BENGALURU  PROCESS ENGINEER
# 3           3  BENGALURU                SENIOR SOFTWARE ENGINEER
# 4           4  BENGALURU                        GRAPHIC DESIGNER
#
#                               Sector         Eligibility    salary  Month  \
# 0  Sales/Retail/Business Development  BTech BE  ME MTech   35000.0      7
# 1           Customer Service/Support        BSc  Diploma   50000.0      9
# 2                        Engineering           MPhil PhD  150000.0      7
# 3            IT/Software Development  BTech BE  ME MTech   60000.0      5
# 4                    Creative/Design     BDS  MBBS  BAMS   30000.0      7
#
#    vacancies
# 0        8.0
# 1        8.0
# 2        3.0
# 3        2.0
# 4        2.0
